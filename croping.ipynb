# %% [markdown]
# <a href="https://colab.research.google.com/github/Vanyaa27/Machine-Learning/blob/main/croping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread('drip2.jpeg')
print(img.shape) # Print image shape
plt.imshow(img)
# Out:
# (400, 267, 3)

# %%
# Cropping an image
cropped_image = img[0:100, 90:170]

# %%
plt.title("Cropped Image")
plt.imshow(cropped_image)
